# %%
#Kirjastot ja päivä laskenta
import pandas as pd
import matplotlib.pyplot as plt
import requests
from io import StringIO
import time

plt.close("all")

def isleapyear(year):
    return year % 400 == 0 or year % 100 != 0 and year % 4 == 0

def calculatedays(day, month, year):
    days = 0
    
    if month == 0:
        days = day
    elif month == 1:
        days = day + 31
    elif month == 2:
        if isleapyear(year) == True:
            days = day + 31 + 29
        else:
            days = day + 31 + 28
    elif month == 3:
        if isleapyear(year) == True:
            days = day + 31 + 29 + 31
        else:
            days = day + 31 + 28 + 31
    elif month == 4:
        if isleapyear(year) == True:
            days = day + 31 + 29 + 31 + 30
        else:
            days = day + 31 + 28 + 31 + 30
    elif month == 5:
        if isleapyear(year) == True:
            days = day + 31 + 29 + 31 + 30 + 31
        else:
            days = day + 31 + 28 + 31 + 30 + 31
    elif month == 6:
        if isleapyear(year) == True:
            days = day + 31 + 29 + 31 + 30 + 31 + 30
        else:
            days = day + 31 + 28 + 31 + 30 + 31 + 30
    elif month == 7:
        if isleapyear(year) == True:
            days = day + 31 + 29 + 31 + 30 + 31 + 30 + 31
        else:
            days = day + 31 + 28 + 31 + 30 + 31 + 30 + 31
    elif month == 8:
        if isleapyear(year) == True:
            days = day + 31 + 29 + 31 + 30 + 31 + 30 + 31 + 31
        else:
            days = day + 31 + 28 + 31 + 30 + 31 + 30 + 31 + 31
    elif month == 9:
        if isleapyear(year) == True:
            days = day + 31 + 29 + 31 + 30 + 31 + 30 + 31 + 31 + 30
        else:
            days = day + 31 + 28 + 31 + 30 + 31 + 30 + 31 + 31 + 30
    elif month == 10:
        if isleapyear(year) == True:
            days = day + 31 + 29 + 31 + 30 + 31 + 30 + 31 + 31 + 30 + 31
        else:
            days = day + 31 + 28 + 31 + 30 + 31 + 30 + 31 + 31 + 30 + 31
    elif month == 11:
        if isleapyear(year) == True:
            days = day + 31 + 29 + 31 + 30 + 31 + 30 + 31 + 31 + 30 + 31 + 30
        else:
            days = day + 31 + 28 + 31 + 30 + 31 + 30 + 31 + 31 + 30 + 31 + 30
    
    return days

def generateurl(days, year):
    urlyear = year - 2000
    url = "https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_" + str(lamid) + "_" + str(urlyear) + "_" + str(days) + ".csv"
    return url

def getdata(days, year):
    url = generateurl(days, year)
    response_API = requests.get(url)
    if response_API.status_code == 200:
        data = response_API.text
        csvString = StringIO(data)
        result = pd.read_csv(csvString, header=None, delimiter=';')
    else:
        result = 404
    return result

# %%
#Ohjelmassa käytettävät arvot
#README.md voi tarkistaa käytettävät lamid:t
#Lam pisteen id
lamid = 10
#Aloituspäivä
day = 1
month = 5  # 0-11  0=Tammikuu  11=Joulukuu
year = 2021
#Lopetuspäivä
day2 = 30
month2 = 5  # 0-11  0=Tammikuu  11=Joulukuu
year2 = 2023

#car type 9 = High Capacity Truck
car_type = 9
#loop delay
delay = 1.5

startday = calculatedays(day, month, year)
endday = calculatedays(day2, month2, year2)
if year > year2:
    temp1 = year
    temp2 = year2
    year1 = temp2
    year2 = temp1
if year == year2 and startday > endday:
    temp1 = startday
    temp2 = endday
    startday = temp2
    endday = temp1
loops = endday - startday +1
if loops < 1 and isleapyear(year) == True:
    loops = 366-startday+endday+1
if loops < 1:
    loops = 365-startday+endday+1
if year < year2 and startday == endday:
    years = year2 - year
    loops = years * 365
if year < year2 and startday < endday:
    years = year2 - year
    loops = loops + years * 365 -1

dataholder = pd.DataFrame()
starttime = time.time()
estimated_time = delay*loops + 0.5*loops
print("Arvioitu datan haku aika: " + str(estimated_time) + ' sekuntia')
print("Haetaan dataa...")
notfound = 0

for i in range(loops):
    days = startday + i
    
    if days > 365 and isleapyear(year) == False:
        if(year2 - year) == 1:
            days = days - 365 
            url = generateurl(days, year2)
        if (year2 - year) > 1:
            days = days - 365
            url = generateurl(days, year+1)
            if days > 366 and isleapyear(year+1) == True:
                days = days - 366
                url = generateurl(days, year+2)
                if days > 365:
                    days = days - 365
                    url = generateurl(days, year+3)
            elif days > 365 and isleapyear(year+1) == False:
                days = days - 365
                url = generateurl(days, year+2)
                if days > 365:
                    days = days - 365
                    url = generateurl(days, year+3)
        response_API = requests.get(url)
        if response_API.status_code == 200:
            data = response_API.text
            csvString = StringIO(data)
            result = pd.read_csv(csvString, header=None, delimiter=';')
            parseddata = result.loc[(result[10] == car_type) & (result[12] == 0)]
            dataholder = pd.concat([dataholder, parseddata])
            #print("data found")
        else:
            print(str(url) + " " + str(response_API))
            notfound = notfound + 1
    elif days > 366 and isleapyear(year) == True:
        if (year2 - year) == 1:
            days = days - 366
            url = generateurl(days, year2)
        if (year2 - year) > 1:
            days = days - 365
            url = generateurl(days, year+1)
            if days > 365:
                days = days - 365
                url = generateurl(days, year+2)
                if days > 365:
                    days = days - 365
                    url = generateurl(days, year+3)
        response_API = requests.get(url)
        if response_API.status_code == 200:
            data = response_API.text
            csvString = StringIO(data)
            result = pd.read_csv(csvString, header=None, delimiter=';')
            parseddata = result.loc[(result[10] == car_type) & (result[12] == 0)]
            dataholder = pd.concat([dataholder, parseddata])
            #print("data found")
        else:
            print(str(url) + " " + str(response_API))
            notfound = notfound + 1
    else: 
        url = generateurl(days, year)
        response_API = requests.get(url)
        if response_API.status_code == 200:
            data = response_API.text
            csvString = StringIO(data)
            result = pd.read_csv(csvString, header=None, delimiter=';')
            parseddata = result.loc[(result[10] == car_type) & (result[12] == 0)]
            dataholder = pd.concat([dataholder, parseddata])
            #print("data found")
        else:
            print(str(url) + " " + str(response_API))
            notfound = notfound + 1
    time.sleep(delay)

endtime = time.time()
totaltime = endtime - starttime

print("Datan hakeminen valmis: " + str(totaltime) + ' sekuntia')
if notfound > 0:
    print(str(notfound) + " päivältä ei löytynyt dataa")

data1 = []
data2 = []
data3 = []
list_data = []

for i in range(24):
    timedata = dataholder.loc[(dataholder[10] == car_type) & (dataholder[3] == i)]
    data_array = [timedata]
    loopeddata = pd.concat(data_array)
    time_mean = loopeddata.iloc[:, 3].mean()
    speeds_mean = loopeddata.iloc[:, 11].mean()
    #car_count = loopeddata.iloc[:, 3].value_counts()[i]
    data_list = loopeddata.iloc[:, 11].tolist()
    list_data.append(data_list)
    data1.append(time_mean)
    data2.append(speeds_mean)
    #data3.append(car_count)

list = {'hours':data1, 'average-speeds':data2}
df = pd.DataFrame(list)

print('lamid: ' + str(lamid) + ' datan järjestely valmis')
# Out:
# Arvioitu datan haku aika: 1518.0 sekuntia
# Haetaan dataa...
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_152.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_153.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_154.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_155.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_156.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_157.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_158.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_159.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_160.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_161.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_162.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_163.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_164.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_165.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_166.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_167.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_168.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_169.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_170.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_171.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_172.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_173.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_174.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_175.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_176.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_177.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_178.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_179.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_180.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_181.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_182.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_183.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_184.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_185.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_186.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_187.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_188.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_189.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_190.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_191.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_192.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_193.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_194.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_195.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_196.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_197.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_198.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_199.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_200.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_201.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_202.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_203.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_204.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_205.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_206.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_207.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_208.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_209.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_210.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_211.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_212.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_213.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_214.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_215.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_216.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_217.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_218.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_219.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_220.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_221.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_222.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_223.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_224.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_225.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_226.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_227.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_228.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_229.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_230.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_231.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_232.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_233.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_234.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_235.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_236.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_237.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_238.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_239.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_240.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_241.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_242.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_243.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_244.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_245.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_246.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_247.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_248.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_249.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_250.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_251.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_252.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_253.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_254.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_255.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_256.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_257.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_258.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_259.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_260.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_261.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_262.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_263.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_264.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_265.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_266.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_267.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_268.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_269.csv <Response [404]>
# https://tie.digitraffic.fi/api/tms/v1/history/raw/lamraw_10_21_270.csv <Response [404]>
# Datan hakeminen valmis: 1462.2107710838318 sekuntia
# 119 päivältä ei löytynyt dataa
# lamid: 10 datan järjestely valmis

# %%
#Näytä data boxplot ja violinplot
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(12,12))
day_range = loops - notfound
axs[0].boxplot(list_data)
axs[0].set_title("Boxplot")

#Violinplot toimii, mutta ei toimi kun on vajaata dataa
axs[1].violinplot(list_data)
axs[1].set_title("Violinplot")

print("lamid:", str(lamid))
print("Keskimääräiset nopeudet HCT " + str(day_range) + " päivän ajalta")
plt.show
# Out:
# lamid: 10
# Keskimääräiset nopeudet HCT 640 päivän ajalta
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Näytä järjestetyn datan kuvaaja
day_range = loops - notfound

#df.plot(x='hours', y='speeds', kind='bar')
df.plot(x='hours', y='average-speeds')

print("lamid:", str(lamid))
print("Keskimääräiset nopeudet " + str(day_range) + " päivän ajalta")
# Out:
# lamid: 1323
# Keskimääräiset nopeudet 759 päivän ajalta

# %%
print("lamid:", str(lamid))
print(df) #print graph as a list
